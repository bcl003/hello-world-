# %% [markdown]
# scientific question: Are there shared transcription factors or pathways  or expression levels that could serve as genomic evidence for convergent evolution of endothermy in birds and humans?

# %% [markdown]
# If humans and birds are both endothermic even though their most recent ancestor was cold-blooded, there could there be genomic evidence present that could prove convergent evolution in the form of similar transcription factors, pathways and expression levels.

# %% [markdown]
# we will analyze TLRs in birds and humans to see if there is evidence of convergent evolution in the form of shared genetic features.
# I will use pairwise sequence alignment between the human and bird TLRs,  I will do this by examining the similarities and differences between the genomes and seeing if there's anything that I can use the explain the similar evolution to endothermy from a coldblooded ancestor. I will also use Homology modeling in order to see the structure of human and bird TLRs in order to see whether or not the structures play a role or not in the development of this phenotype.

# %% [markdown]
# In order to analyze the TLRs for genomic evidence of convergent evolution, we will analyze human TLR signaling regulator and TLR for the Hawaiian crow.

# %%
import pandas as pd
bird= pd.read_csv('Downloads/crow.tsv',sep='\t')
bird.head()
# Out:
#      gene_id   gene_symbol                                        description  \
# 0  125333467  LOC125333467  TLR adapter interacting with SLC15A4 on the ly...
# 1  125333467  LOC125333467  TLR adapter interacting with SLC15A4 on the ly...
# 2  125333467  LOC125333467  TLR adapter interacting with SLC15A4 on the ly...
# 3  125333467  LOC125333467  TLR adapter interacting with SLC15A4 on the ly...
#
#       scientific_name    common_name  tax_id                genomic_range  \
# 0  Corvus hawaiiensis  hawaiian crow  134902  NC_063226.1:5171146-5175191
# 1  Corvus hawaiiensis  hawaiian crow  134902  NC_063226.1:5171146-5175191
# 2  Corvus hawaiiensis  hawaiian crow  134902  NC_063226.1:5171146-5175191
# 3  Corvus hawaiiensis  hawaiian crow  134902  NC_063226.1:5171146-5175191
#
#   orientation location       gene_type transcript_accession  \
# 0           -   chr 14  PROTEIN_CODING       XM_048319372.1
# 1           -   chr 14  PROTEIN_CODING       XM_048319369.1
# ...

# %%
human= pd.read_csv('Downloads/human.tsv',sep='\t')
human.head()
# Out:
#    gene_id gene_symbol                                 description  \
# 0    81622     UNC93B1  unc-93 homolog B1, TLR signaling regulator
# 1    81622     UNC93B1  unc-93 homolog B1, TLR signaling regulator
# 2    81622     UNC93B1  unc-93 homolog B1, TLR signaling regulator
#
#   scientific_name common_name  tax_id  \
# 0    Homo sapiens       human    9606
# 1    Homo sapiens       human    9606
# 2    Homo sapiens       human    9606
#
#                                        genomic_range orientation location  \
# 0  NC_000011.10:67991100-68004097;NC_060935.1:679...         -;-   chr 11
# 1  NC_000011.10:67991100-68004097;NC_060935.1:679...         -;-   chr 11
# 2  NC_000011.10:67991100-68004097;NC_060935.1:679...         -;-   chr 11
#
#         gene_type transcript_accession        transcript_name  \
# 0  PROTEIN_CODING          NM_030930.4                    NaN
# 1  PROTEIN_CODING       XM_011545290.1  transcript variant X1
# ...
